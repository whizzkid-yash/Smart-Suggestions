# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers.legacy import SGD
import random

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intent.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
# Out:
# 40 documents
# 7 classes ['about', 'complaint', 'create_account', 'goodbye', 'greeting', 'help', 'thanks']
# 59 unique lemmatized words ["'s", ',', 'a', 'about', 'account', 'an', 'anyone', 'are', 'awesome', 'bye', 'can', 'chatting', 'complaint', 'could', 'create', 'day', 'do', 'for', 'give', 'good', 'goodbye', 'hand', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hola', 'how', 'i', 'is', 'later', 'me', 'name', 'need', 'new', 'next', 'nice', 'open', 'please', 'raise', 'see', 'service', 'support', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'want', 'what', 'whats', 'who', 'you', 'your']

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\wetec\AppData\Local\Temp\ipykernel_15496\3528693901.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created and saved")
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9654 - accuracy: 0.2000
# Epoch 2/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8761 - accuracy: 0.2750
# Epoch 3/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8800 - accuracy: 0.2250
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8036 - accuracy: 0.1750
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7462 - accuracy: 0.2750
# Epoch 6/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6168 - accuracy: 0.4000
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5201 - accuracy: 0.4250
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5523 - accuracy: 0.5250
# Epoch 9/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.4022 - accuracy: 0.5000
# Epoch 10/200
# 8/8 [==============================] - 0s 1000us/step - loss: 1.1509 - accuracy: 0.7250
# Epoch 11/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2914 - accuracy: 0.5750
# Epoch 12/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.1704 - accuracy: 0.6000
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9860 - accuracy: 0.7750
# Epoch 14/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8761 - accuracy: 0.7250
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.8250
# Epoch 16/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7793 - accuracy: 0.8000
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5763 - accuracy: 0.8500
# Epoch 18/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6099 - accuracy: 0.8500
# Epoch 19/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5577 - accuracy: 0.8500
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5781 - accuracy: 0.8000
# Epoch 21/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5127 - accuracy: 0.8250
# Epoch 22/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4837 - accuracy: 0.8750
# Epoch 23/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.9500
# Epoch 24/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4088 - accuracy: 0.9250
# Epoch 25/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3114 - accuracy: 0.9500
# Epoch 26/200
# 8/8 [==============================] - 0s 999us/step - loss: 0.2922 - accuracy: 0.9250
# Epoch 27/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2609 - accuracy: 0.9500
# Epoch 28/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2225 - accuracy: 0.9750
# Epoch 29/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3835 - accuracy: 0.8500
# Epoch 30/200
# 8/8 [==============================] - 0s 858us/step - loss: 0.2051 - accuracy: 1.0000
# Epoch 31/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.9500
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1792 - accuracy: 0.9750
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1856 - accuracy: 0.9500
# Epoch 34/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1852 - accuracy: 0.9750
# Epoch 35/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0769 - accuracy: 1.0000
# Epoch 36/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2593 - accuracy: 0.9500
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 1.0000
# Epoch 38/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2109 - accuracy: 0.9250
# Epoch 39/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1349 - accuracy: 0.9500
# Epoch 40/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0829 - accuracy: 1.0000
# Epoch 41/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2202 - accuracy: 0.9500
# Epoch 42/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1601 - accuracy: 0.9250
# Epoch 43/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2299 - accuracy: 0.9000
# Epoch 44/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0877 - accuracy: 0.9750
# Epoch 45/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1578 - accuracy: 0.9500
# Epoch 46/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1145 - accuracy: 1.0000
# Epoch 47/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1485 - accuracy: 0.9750
# Epoch 48/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1020 - accuracy: 1.0000
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1581 - accuracy: 0.9750
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0870 - accuracy: 0.9750
# Epoch 51/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 52/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.1934 - accuracy: 0.9250
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.9750
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9750
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.9750
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 1.0000
# Epoch 59/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0950 - accuracy: 0.9500
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 63/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0660 - accuracy: 1.0000
# Epoch 64/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.9750
# Epoch 65/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 66/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0633 - accuracy: 0.9750
# Epoch 67/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1250 - accuracy: 0.9500
# Epoch 68/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0623 - accuracy: 1.0000
# Epoch 69/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 70/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0784 - accuracy: 0.9750
# Epoch 71/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0737 - accuracy: 0.9750
# Epoch 72/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 73/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 74/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0617 - accuracy: 0.9750
# Epoch 75/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9750
# Epoch 76/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 0.9750
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 78/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 79/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 80/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 81/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 82/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 84/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 86/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 87/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0605 - accuracy: 0.9750
# Epoch 88/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 89/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9500
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9750
# Epoch 92/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 93/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 94/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0631 - accuracy: 0.9750
# Epoch 95/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 96/200
# 8/8 [==============================] - 0s 859us/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 98/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0559 - accuracy: 0.9750
# Epoch 99/200
# 8/8 [==============================] - 0s 858us/step - loss: 0.0353 - accuracy: 0.9750
# Epoch 100/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0638 - accuracy: 0.9750
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 102/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0863 - accuracy: 0.9750
# Epoch 103/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 104/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 105/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1027 - accuracy: 0.9750
# Epoch 106/200
# 8/8 [==============================] - 0s 991us/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 107/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 109/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 110/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0542 - accuracy: 0.9750
# Epoch 111/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9750
# Epoch 113/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 114/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 115/200
# 8/8 [==============================] - 0s 857us/step - loss: 0.0464 - accuracy: 1.0000
# Epoch 116/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9750
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 124/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 125/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0450 - accuracy: 1.0000
# Epoch 126/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 127/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 128/200
# 8/8 [==============================] - 0s 856us/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 130/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 131/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 136/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 138/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0673 - accuracy: 0.9750
# Epoch 139/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 140/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 141/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 142/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 143/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 144/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 146/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 0.9750
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 151/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 153/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 154/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 156/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 157/200
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 159/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 160/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 161/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9750
# Epoch 163/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0283 - accuracy: 0.9750
# Epoch 164/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 165/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 166/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0519 - accuracy: 0.9750
# Epoch 167/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 168/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 170/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 171/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 172/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 173/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 175/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0480 - accuracy: 0.9750
# Epoch 176/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 177/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 179/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 180/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 181/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 182/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0346 - accuracy: 0.9750
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 184/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0381 - accuracy: 0.9750
# Epoch 185/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 0.9750
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 189/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 190/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 193/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 194/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 196/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 199/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 200/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# model created and saved

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from tensorflow.keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intent.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))


def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res


#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
    
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
            
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
 

base = Tk()
base.title("Chatbot")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#25cdf7", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
